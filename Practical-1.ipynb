# %%
print('same\'s class')
# Out:
# same's class

# %%
print("\\")
# Out:
# \

# %%
string = "h1234567i\newtryhjrewe"
print(string)
# Out:
# h1234567i
# ewtryhjrewe

# %%
print('''
\'hello \n123\'''')
# Out:
# 'hello
# 123'

# %%
print('Romil \n \\ \"')
# Out:
# Romil
#  \ "

# %%
'A car ' + '''and''' + " a truck"
# Out:
# 'A car and a truck'

# %%
5*'2'
# Out:
# '22222'

# %%
print(3*'A car\n'+4*'a truck\n')
# Out:
# A car
# A car
# A car
# a truck
# a truck
# a truck
# a truck

# %%
"abc " "def"
# Out:
# 'abc def'

# %%
a = 5
b = 4
c = a + b
print("addition of " + str(a) + " and " + str(b) + " is " +str(c))
# Out:
# addition of 5 and 4 is 9

# %%
print("this is {}".format("class"))
# Out:
# this is class

# %%
print("sammy studies {0} as he found it {1}".format("python","c++"))
# Out:
# sammy studies python as he found it c++

# %%
print('sammy goes to {1} by {0} and works {pr}'.format('car','school',pr='hard'))
# Out:
# sammy goes to school by car and works hard

# %%
st = "my name is Romil."
st[6]
# Out:
# 'e'

# %%
st[0:6]
# Out:
# 'my nam'

# %%
st[4:9]
# Out:
# 'ame i'

# %%
st[-6]
# Out:
# 'R'

# %%
st[-3:]
# Out:
# 'il.'

# %%
st[1::2]
# Out:
# 'ynm sRml'

# %%
st.count('n')
# Out:
# 1

# %%
st.find('s')
# Out:
# 9
