# %%
any_list = [1, 2, 3, 4, 5]
any_list [3] = 20
any_list
# Out:
# [1, 2, 3, 20, 5]

# %%
any_tuple=(54,3,65,24,76)

# %%
any_tuple.append(9)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 any_tuple.append(9)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
any_tuple[3]=9
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 any_tuple[3]=9
#
# TypeError: 'tuple' object does not support item assignment

# %%
stri='My name is '
stri[0]=2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 stri='My name is '
# ----> 2 stri[0]=2
#
# TypeError: 'str' object does not support item assignment

# %%
stri2='nit'
stri+stri2
# Out:
# 'My name is nit'

# %%
any_list[3] = 10
any_list
# Out:
# [1, 2, 3, 10, 5]

# %%
a_list = [1, 'food', [4, 5]]
a_list
# Out:
# [1, 'food', [4, 5]]

# %%
a_tuple = (1, 'food', [4, 5])

# %%
a_tuple[2].extend([2,3,4])
a_tuple
# Out:
# (1, 'food', [4, 5, 2, 3, 4])

# %%
a_tuple[2] = (7,8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 a_tuple[2] = (7,8)
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = 'This is string. String is immutable'
a
a[4]
# Out:
# ' '

# %%
a[4] = 'U'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 a[4] = 'U'
#
# TypeError: 'str' object does not support item assignment

# %%
fish_list=['Bowfin','Cod','Herring','Ray','Salmon','Tuna']
fish_list
# Out:
# ['Bowfin', 'Cod', 'Herring', 'Ray', 'Salmon', 'Tuna']

# %%
fish_list.append('Wahoo')
fish_list
# Out:
# ['Bowfin', 'Cod', 'Herring', 'Ray', 'Salmon', 'Tuna', 'Wahoo']

# %%
fish_list.insert(5,'Sunfish')
fish_list
# Out:
# ['Bowfin', 'Cod', 'Herring', 'Ray', 'Salmon', 'Sunfish', 'Tuna', 'Wahoo']

# %%
fish_w_list=['Walleye','Weakfish','Weakfish','Whiting']
fish_list.extend(fish_w_list)
fish_w_list
# Out:
# ['Walleye', 'Weakfish', 'Weakfish', 'Whiting']

# %%
fish_list.remove('Cod')
print(fish_list)
# Out:
# ['Bowfin', 'Herring', 'Ray', 'Salmon', 'Sunfish', 'Tuna', 'Wahoo', 'Walleye', 'Weakfish', 'Weakfish', 'Whiting']

# %%
fish_list[0::2]
# Out:
# ['Bowfin', 'Ray', 'Sunfish', 'Wahoo', 'Weakfish', 'Whiting']

# %%
fish_list[-4:-1]
# Out:
# ['Walleye', 'Weakfish', 'Weakfish']

# %%
fish_list[::-1]
# Out:
# ['Whiting',
#  'Weakfish',
#  'Weakfish',
#  'Walleye',
#  'Wahoo',
#  'Tuna',
#  'Sunfish',
#  'Salmon',
#  'Ray',
#  'Herring',
#  'Bowfin']

# %%
fish_list.count('Cod')
# Out:
# 0

# %%
fish_age = [1, 2, 3, 5, 1, 2, 1, 3, 1]
fish_age.count(1)
# Out:
# 4

# %%
fish_age.clear()
fish_age
# Out:
# []

# %%
from functools import reduce

lst = [1,2,3,4]
def mult(x,y):
    return x+y

prod = reduce(mult, lst)
print(prod)
# Out:
# 10

# %%
x = ('apple', 'banana', 'cherry')
a = "geek"
y = enumerate(x)
z = enumerate(a)

print("Return type:", type(y))
print(enumerate(x))
# Out:
# Return type: <class 'enumerate'>
# ...

# %%
print(list(enumerate(x)))
print(list(z))
# Out:
# [(0, 'apple'), (1, 'banana'), (2, 'cherry')]
# [(0, 'g'), (1, 'e'), (2, 'e'), (3, 'k')]

# %%
l1 = ["eat","sleep","repeat"]
for ele in enumerate(l1):
    print(ele)
for count,ele in enumerate(l1,100):
    print (count,ele)
for count,ele in enumerate(l1):
  print(count)
  print(ele)
# Out:
# (0, 'eat')
# (1, 'sleep')
# (2, 'repeat')
# 100 eat
# 101 sleep
# 102 repeat
# 0
# eat
# 1
# sleep
# 2
# repeat

# %%
di1 = {"roll no": [3,5,6,7],"Name": ["a","b","c","d"]}
type(di1)
# Out:
# dict

# %%
a = [1,2,None,4,None,5]
total = 0
for num in a:
    if num is None:
        continue
    total+= num
total
# Out:
# 12

# %%
a = [1,2,34,4,43,5]
total = 0
for num in a:
    if num == 4:
        break
    total+= num
total
# Out:
# 37

# %%
x =0 
y =1
itr = 1
length = 5
while\
# Out:
#   Cell In[1], line 5
#     while\
#           ^
# _IncompleteInputError: incomplete input
